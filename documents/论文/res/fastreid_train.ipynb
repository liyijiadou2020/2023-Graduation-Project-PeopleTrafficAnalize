# %%
# !git clone https://github.com/JDAI-CV/fast-reid.git
# Out:
# Cloning into 'fast-reid'...
# remote: Enumerating objects: 5908, done.
# remote: Counting objects: 100% (5908/5908), done.
# remote: Compressing objects: 100% (2181/2181), done.
# remote: Total 5908 (delta 3681), reused 5695 (delta 3600), pack-reused 0
# Receiving objects: 100% (5908/5908), 13.79 MiB | 26.50 MiB/s, done.
# Resolving deltas: 100% (3681/3681), done.

# %%
# !sudo update-alternatives --config python3

# %%
# !python --version
# Out:
# Python 3.8.10

# %%
cd ..
# Out:
# /content/fast-reid

# %%
ls
# Out:
# CHANGELOG.md  datasets/  docs/               INSTALL.md    projects/  tools/
# checkpoints/  demo/      fastreid/           LICENSE       README.md
# configs/      docker/    GETTING_STARTED.md  MODEL_ZOO.md  tests/

# %%
# !mkdir checkpoints

# %%
# !unzip datasets/MSMT17_V2.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_033_15_0114noon_1545_1_ex.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_034_15_0114noon_1546_0.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_035_15_0114noon_1546_0_ex.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_036_15_0114noon_1548_1.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_037_15_0114noon_1548_1_ex.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_038_15_0114noon_1549_0.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_039_15_0114noon_1549_0_ex.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_040_15_0114noon_1550_1.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_041_15_0114noon_1550_1_ex.jpg
#    creating: MSMT17_V2/mask_train_v2/0910/
#   inflating: MSMT17_V2/mask_train_v2/0910/0910_000_01_0114noon_0907_5.jpg
#   inflating: MSMT17_V2/mask_train_v2/0910/0910_001_01_0114noon_0907_5_ex.jpg
# ...

# %%
# Out:
# /usr/bin/python3: No module named pip

# %%
# !pip install -r docs/requirements.txt
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 5, in <module>
#     from pip._internal.cli.main import main
# ModuleNotFoundError: No module named 'pip'

# %%
cd ./fastreid/evaluation/rank_cylib/
# Out:
# /content/fast-reid/fastreid/evaluation/rank_cylib

# %%
# !make all
# Out:
# python3 setup.py build_ext --inplace
# Traceback (most recent call last):
#   File "setup.py", line 4, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'
# make: *** [Makefile:2: all] Error 1

# %%
# !python tools/train_net.py --config-file ./configs/MSMT17/sbs_R101-ibn.yml --eval-only MODEL.WEIGHTS checkpoints/msmt_sbs_R101-ibn.pth MODEL.DEVICE "cuda:0"
# Out:
# Traceback (most recent call last):
#   File "tools/train_net.py", line 12, in <module>
#     from fastreid.config import get_cfg
#   File "/content/fast-reid/./fastreid/config/__init__.py", line 7, in <module>
#     from .config import CfgNode, get_cfg, global_cfg, set_global_cfg, configurable
#   File "/content/fast-reid/./fastreid/config/config.py", line 13, in <module>
#     import yaml
# ModuleNotFoundError: No module named 'yaml'

# %%
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.10   2         auto mode
#   1            /usr/bin/python3.10   2         manual mode
#   2            /usr/bin/python3.8    1         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 2
# update-alternatives: using /usr/bin/python3.8 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached https://files.pythonhosted.org/packages/45/b2/6c7545bb7a38754d63048c7696804a0d947328125d81bf12beaa692c3ae3/numpy-1.19.5-cp36-cp36m-manylinux1_x86_64.whl
# ...

# %%
# !pip install matplotlib scipy Pillow prettytable easydict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached https://files.pythonhosted.org/packages/09/03/b7b30fa81cb687d1178e085d0f01111ceaea3bf81f9330c937fb6f6c8ca0/matplotlib-3.3.4-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/c8/89/63171228d5ced148f5ced50305c89e8576ffc695a90b58fe5bb602b910c2/scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/7d/2a/2fc11b54e2742db06297f7fa7f420a0e3069fdcf0e4b57dfec33f0b08622/Pillow-8.4.0.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/9e/6d/40a24eaa03ea4418129708fd3f0f17eda73d568f16d4d4fd412566168b4c/prettytable-2.5.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/55/83/0d1ee7962f3ba3fbe9eebe67eb484f6745995c9af045c0ebe5f33564cba0/easydict-1.10.tar.gz
# ...
#     100% |████████████████████████████████| 256kB 9.3MB/s
# ...

# %%
# !python --version
